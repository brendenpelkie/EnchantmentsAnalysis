# %%
import tabula
import tabulate
import pickle
import pandas as pd
import camelot

# %%
camelot.__version__
# Out:
# '0.9.0'

# %%
def save_object(obj, filename):
    """
    Function to save an object in a pickle. Uses pickle highest priority

    Parameters:
    -----------
    obj - python object to save
    filename (str): desired filename
    """
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)

# %%
df2 = camelot.read_pdf('fseprd695975.pdf', pages = '1')

# %%
df2[0].df
# Out:
#                           0                     1   \
# 0   Preferred Entry \nDate 1  Preferred Division 1
# 1                    6/21/21         Colchuck Zone
# 2                    8/31/21         Colchuck Zone
# 3                    8/19/21         Colchuck Zone
# 4                    8/12/21         Colchuck Zone
# ..                       ...                   ...
# 79                   6/14/21         Colchuck Zone
# 80                   8/12/21         Colchuck Zone
# 81                   7/12/21         Colchuck Zone
# 82                    6/5/21         Colchuck Zone
# 83                    7/9/21         Colchuck Zone
#
#                                      2                                   3   \
# 0   Minimum \nAcceptable \nGroup Size 1  Maximum \nRequested \nGroup Size 1
# 1                                     2                                   2
# 2                                     2                                   2
# ...

# %%
save_object(df, 'enchantmentsdata_tabula.pkl')

# %%
tabulate.tabulate(df)

# %%
df = camelot.read_pdf('fseprd695975.pdf', pages = '1')
df = df[0].df

for i in range(1, 443):
    
    print('Appending page ', i)
    df_new = camelot.read_pdf('fseprd695975.pdf', pages = '{}'.format(i))
    df = pd.concat([df, df_new[0].df])
# Out:
# Appending page  1
# Appending page  2
# Appending page  3
# Appending page  4
# Appending page  5
# Appending page  6
# Appending page  7
# Appending page  8
# Appending page  9
# Appending page  10
# Appending page  11
# Appending page  12
# Appending page  13
# Appending page  14
# Appending page  15
# Appending page  16
# Appending page  17
# Appending page  18
# Appending page  19
# Appending page  20
# Appending page  21
# Appending page  22
# Appending page  23
# Appending page  24
# Appending page  25
# Appending page  26
# Appending page  27
# Appending page  28
# Appending page  29
# Appending page  30
# Appending page  31
# Appending page  32
# Appending page  33
# Appending page  34
# Appending page  35
# Appending page  36
# Appending page  37
# Appending page  38
# Appending page  39
# Appending page  40
# Appending page  41
# Appending page  42
# Appending page  43
# Appending page  44
# Appending page  45
# Appending page  46
# Appending page  47
# Appending page  48
# ...

# %%
df[1:][0]
# Out:
# 1     6/21/21
# 2     8/31/21
# 3     8/19/21
# 4     8/12/21
# 5      7/9/21
#        ...
# 79    9/11/21
# 80     9/7/21
# 81     9/6/21
# 82     9/6/21
# 83    9/10/21
# Name: 0, Length: 37211, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df.to_csv('Enchantmentsdata_2021.csv')

# %%
df = df.drop(df[0][df[0]=='Preferred Entry \nDate 1'].index)

# %%
df.reset_index(inplace = True)

# %%
df[0] = df[0].astype('datetime64')

# %%
df.groupby([0])

# %%
df
# Out:
#        level_0  index          0                    1  2  3        4  \
# 0            1      1 2021-06-21        Colchuck Zone  2  2  6/28/21
# 1            2      2 2021-08-31        Colchuck Zone  2  2   9/1/21
# 2            3      3 2021-08-19        Colchuck Zone  4  4  8/19/21
# 3            4      4 2021-08-12        Colchuck Zone  8  8  8/19/21
# 4            5      5 2021-07-09        Colchuck Zone  4  4   7/9/21
# ...        ...    ...        ...                  ... .. ..      ...
# 36764    37207     79 2021-09-11  Stuart Zone (stock)  4  4  8/28/21
# 36765    37208     80 2021-09-07  Stuart Zone (stock)  3  3   9/8/21
# 36766    37209     81 2021-09-06  Stuart Zone (stock)  2  2  9/13/21
# 36767    37210     82 2021-09-06  Stuart Zone (stock)  8  8   7/1/21
# 36768    37211     83 2021-09-10  Stuart Zone (stock)  4  4  9/16/21
#
#                            5  6  7        8                      9 10 11  \
# ...
